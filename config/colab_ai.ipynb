# %%
# BLACK RONZER AI VERIFICATION ENGINE
# Upload to: colab.research.google.com
# Runtime > Run all

import requests, time, json

RENDER_URL = "YOUR_RENDER_URL"  # Change this
TELEGRAM_BOT = "8802770166:AAFZxGz4M9QpY7iUQC8auLfN4H7gO_CEdHQ"
CHAT_ID = "6916557418"

print("Black Ronzer AI Online")
print(f"Connected to: {RENDER_URL}")

while True:
    try:
        resp = requests.get(f"{RENDER_URL}/health")
        print(f"[{time.strftime('%H:%M:%S')}] API: {resp.json()}")
    except:
        print("API unreachable")
    time.sleep(300)
